# %%
import pandas as pd

df = pd.read_csv("Datasets/diamonds.csv", index_col=0)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#df["cut"].astype("category").cat.codes

# %%
cut_class_dict = {"Fair":1, "Good":2, "Very Good":3, "Premium":4, "Ideal":5}
clarity_dict = {"I3": 1, "I2": 2, "I1": 3, "SI2": 4, "SI1": 5, "VS2": 6, "VS1": 7, "VVS2": 8, "VVS1": 9, "IF": 10, "FL": 11}
color_dict = {"J": 1,"I": 2,"H": 3,"G": 4,"F": 5,"E": 6,"D": 7}


df["cut"] = df["cut"].map(cut_class_dict)
df["clarity"] = df["clarity"].map(clarity_dict)
df["color"] = df["color"].map(color_dict)

df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 1   0.23    5      6        4   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21    4      6        5   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23    2      6        7   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29    4      2        6   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31    2      1        4   63.3   58.0    335  4.34  4.35  2.75

# %%
import sklearn
from sklearn import svm, preprocessing

#shuffle the model

df = sklearn.utils.shuffle(df)

X = df.drop("price", axis=1).values
X = preprocessing.scale(X)
y = df["price"].values

test_size = 200

X_train = X[:-test_size] 
y_train = y[:-test_size] 

X_test = X[-test_size:]
y_test = y[-test_size:]

clf = svm.SVR(kernel="linear")
clf.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.89515716407862

# %%
for X,y in zip(X_test, y_test):
    print(f"Model: {clf.predict([X])[0]}, Actual:{y}")
# Out:
# Model: -242.22344593509843, Actual:576
# Model: 7961.087212788792, Actual:7056
# Model: -58.74032351720052, Actual:505
# Model: 14273.304429937638, Actual:14185
# Model: 895.2947786799891, Actual:787
# Model: 10769.226896872293, Actual:16513
# Model: 223.9182439229021, Actual:743
# Model: 1170.5920949163178, Actual:958
# Model: 3636.600703571841, Actual:3148
# Model: 591.1352520603132, Actual:620
# Model: 5474.418582518133, Actual:7056
# Model: 1647.1175179116608, Actual:1664
# Model: 431.78520923352426, Actual:736
# Model: 16385.52185508984, Actual:17407
# Model: 1512.4634471211457, Actual:1029
# Model: 10157.022497543829, Actual:9428
# Model: 11485.323465255062, Actual:9658
# Model: 1105.2389629369973, Actual:1050
# Model: 5177.370517182116, Actual:6132
# Model: 118.42630273982468, Actual:477
# Model: 2327.748501062607, Actual:2066
# Model: 322.9961932004612, Actual:645
# Model: 4691.1852975473885, Actual:4924
# Model: 10540.668806308147, Actual:15544
# Model: 583.0672041353077, Actual:525
# Model: 4521.35969358383, Actual:3906
# Model: 498.69328426945776, Actual:854
# Model: 5977.443076345757, Actual:6788
# Model: 1915.707131573276, Actual:1585
# Model: 966.1220913345928, Actual:814
# Model: 5973.100850245673, Actual:5385
# Model: 1713.203464075828, Actual:1668
# Model: 801.5237632851131, Actual:692
# Model: 569.9348771653381, Actual:724
# Model: 6202.837260909646, Actual:7404
# Model: 1104.6727613363987, Actual:1227
# Model: 2533.921625823774, Actual:2188
# Model: 2157.3917632127723, Actual:1580
# Model: 2593.101804746285, Actual:1657
# Model: 4201.164951933879, Actual:4042
# Model: -85.75243973687793, Actual:630
# Model: 1010.1520466190714, Actual:877
# Model: 3258.6265998612475, Actual:2633
# Model: 4909.466796955039, Actual:4395
# Model: 195.9121843146586, Actual:589
# Model: 998.7809107373487, Actual:569
# Model: 3538.9915041805757, Actual:2816
# Model: 8083.860571430063, Actual:8794
# Model: 673.4641116676848, Actual:733
# Model: 766.3803076669737, Actual:581
# Model: 3347.0935328065743, Actual:2818
# Model: 1220.722814752573, Actual:1131
# Model: 3734.307801711448, Actual:3595
# Model: 11829.505221234955, Actual:14810
# Model: -539.888132548414, Actual:393
# Model: 9405.75110637933, Actual:14957
# Model: 5370.0848433290175, Actual:6679
# Model: 6738.578935577, Actual:9316
# Model: 3674.933689552189, Actual:3111
# Model: 2820.4473557743786, Actual:3011
# Model: 8607.514711586615, Actual:12219
# Model: 263.95050339299723, Actual:743
# Model: 4719.128756190825, Actual:5243
# Model: 3106.6847694549706, Actual:3541
# Model: 1738.6941175149811, Actual:1720
# Model: 8213.317182584198, Actual:7504
# Model: 4458.962211947096, Actual:4253
# Model: 809.5111438071849, Actual:951
# Model: 905.8396988430977, Actual:1040
# Model: 2879.4346660327164, Actual:2512
# Model: 10.190382208475512, Actual:534
# Model: 5354.510563466144, Actual:4932
# Model: 717.2623895256888, Actual:1002
# Model: 4649.639297765583, Actual:3597
# Model: 5039.185360521864, Actual:4537
# Model: 5188.033502111887, Actual:6529
# Model: -573.6463171521632, Actual:537
# Model: 4415.651820404178, Actual:4540
# Model: 1983.95227868776, Actual:1906
# Model: 2267.556400682688, Actual:1952
# Model: 460.62683968488636, Actual:474
# Model: 1522.588998075852, Actual:1265
# Model: 1622.2957479146287, Actual:1213
# Model: 738.5300198861132, Actual:800
# Model: 690.3269378241662, Actual:692
# Model: 256.5399306264035, Actual:743
# Model: 3614.7488496080978, Actual:3312
# Model: 5194.38453399685, Actual:4871
# Model: 1380.691068331626, Actual:929
# Model: -55.041655313177216, Actual:470
# Model: 2232.2048316200235, Actual:1851
# Model: 4276.070350558397, Actual:4223
# Model: 9779.14390318112, Actual:9801
# Model: 5117.345480013996, Actual:4568
# Model: 1356.084833830685, Actual:1299
# Model: 1167.7559434557966, Actual:1024
# Model: 4837.961675543783, Actual:3928
# Model: 5127.272242268678, Actual:6288
# Model: 676.479506367476, Actual:755
# Model: 673.0489697240646, Actual:665
# Model: 4479.997526267954, Actual:4291
# Model: 3683.4538538262555, Actual:3145
# Model: 5272.04174500941, Actual:5192
# Model: 300.6211152896785, Actual:579
# Model: 676.329915662755, Actual:811
# Model: 5825.540303220561, Actual:4783
# Model: 135.15165303757203, Actual:579
# Model: 368.9298753232524, Actual:710
# Model: 5722.941410005929, Actual:7699
# Model: 456.0428674713585, Actual:700
# Model: 1257.7961573783264, Actual:1174
# Model: 678.6531010631111, Actual:781
# Model: 4931.3951045878675, Actual:5249
# Model: 5461.186043251544, Actual:6183
# Model: 920.7986549691154, Actual:1269
# Model: 5638.916929984738, Actual:4789
# Model: 4549.848928893232, Actual:4497
# Model: 727.882723422279, Actual:816
# Model: 8386.031508677936, Actual:8107
# Model: 2316.3374854901676, Actual:1743
# Model: 4059.576347352474, Actual:3685
# Model: 9540.33442760205, Actual:14833
